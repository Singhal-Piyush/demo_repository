# %% [markdown]
# # Electoral Bond India

# %% [markdown]
# #### Loading the Packages and Library

# %%
# import numpy as np
import pandas as pd 
# import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-87-7a0fdebfb612> in <module>
#       3 # import matplotlib.pyplot as plt
#       4
# ----> 5 import tabula as tb
#
# ModuleNotFoundError: No module named 'tabula'

# %% [markdown]
# #### Loading the Data

# %%
purchaser_data = pd.read_csv("G://Dataset for Data Analysis//Electroral Bond Data//ED_Purchaser_Details.csv")

# %% [markdown]
# #### Metadata of dataframe

# %%
purchaser_data.head(5)
# Out:
#   Sr No.      Reference No  (URN) Journal Date Date of\rPurchase  \
# 0      1  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 1      2  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 2      3  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 3      4  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 4      5  00001201904120000001166  12/Apr/2019       12/Apr/2019
#
#   Date of Expiry Name of the Purchaser Prefix Bond\rNumber Denominations  \
# 0    26/Apr/2019   A B C INDIA LIMITED     TL        11448     10,00,000
# 1    26/Apr/2019   A B C INDIA LIMITED     TL        11447     10,00,000
# 2    26/Apr/2019   A B C INDIA LIMITED     TL        11441     10,00,000
# 3    26/Apr/2019   A B C INDIA LIMITED     OL         1113      1,00,000
# 4    26/Apr/2019   A B C INDIA LIMITED     OL         1118      1,00,000
#
#   Issue Branch Code Issue Teller Status
# 0             00001      5899230   Paid
# 1             00001      5899230   Paid
# ...

# %%
pd.set_option("display.max_row",100)
purchaser_data.head(100)
# Out:
#     Sr No.      Reference No  (URN)  Journal Date  Date of\rPurchase  \
# 0        1  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 1        2  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 2        3  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 3        4  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 4        5  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 5        6  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 6        7  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 7        8  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 8        9  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 9       10  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 10      11  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 11      12  00001201904120000001166   12/Apr/2019        12/Apr/2019
# 12      13  00001201904120000001166   12/Apr/2019        12/Apr/2019
# ...

# %%
# Drop the rows with column heading in the purchaser_data

temp = purchaser_data

a = []

for i in range(0,len(temp["Sr No."])):
    if temp.iloc[i]["Sr No."]=="Sr No.":
        a.append(i)

# %%
pd_temp = temp.drop(axis=0,index = a,inplace = True)

# %%
print(purchaser_data.dtypes)
print(purchaser_data.columns)
# Out:
# Sr No.                   object
# Reference No  (URN)      object
# Journal Date             object
# Date of\rPurchase        object
# Date of Expiry           object
# Name of the Purchaser    object
# Prefix                   object
# Bond\rNumber             object
# Denominations            object
# Issue Branch Code        object
# Issue Teller             object
# Status                   object
# dtype: object
# Index(['Sr No.', 'Reference No  (URN)', 'Journal Date', 'Date of\rPurchase',
#        'Date of Expiry', 'Name of the Purchaser', 'Prefix', 'Bond\rNumber',
#        'Denominations', 'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
purchaser_data.head()
# Out:
#   Sr No.      Reference No  (URN) Journal Date Date of\rPurchase  \
# 0      1  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 1      2  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 2      3  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 3      4  00001201904120000001166  12/Apr/2019       12/Apr/2019
# 4      5  00001201904120000001166  12/Apr/2019       12/Apr/2019
#
#   Date of Expiry Name of the Purchaser Prefix Bond\rNumber Denominations  \
# 0    26/Apr/2019   A B C INDIA LIMITED     TL        11448     10,00,000
# 1    26/Apr/2019   A B C INDIA LIMITED     TL        11447     10,00,000
# 2    26/Apr/2019   A B C INDIA LIMITED     TL        11441     10,00,000
# 3    26/Apr/2019   A B C INDIA LIMITED     OL         1113      1,00,000
# 4    26/Apr/2019   A B C INDIA LIMITED     OL         1118      1,00,000
#
#   Issue Branch Code Issue Teller Status
# 0             00001      5899230   Paid
# 1             00001      5899230   Paid
# ...

# %%
# Writing the data in csv file 

purchaser_data.to_csv("G:\\Job Projects\\Project 3 - Electoral Bond Data\\Electroral Bond Data\\ED_Purchaser_Details_1.csv",
                     sep = ",",
                     index = False)

# %% [markdown]
# ### Working on EB_Redemption.csv File

# %%
redemption_data = pd.read_csv("G:\\Job Projects\\Project 3 - Electoral Bond Data\\Electroral Bond Data\\ED_Redemption_Details.csv")

# %%
print(redemption_data.columns)
print(redemption_data.shape)
# Out:
# Index(['Sr No.', 'Date of\rEncashment', 'Name of the Political Party',
#        'Account no. of\rPolitical Party', 'Prefix', 'Bond\rNumber',
#        'Denominations', 'Pay Branch\rCode', 'Pay Teller'],
#       dtype='object')
# (20972, 9)

# %%
a = []

for i in range(0,len(redemption_data["Sr No."])):
        if redemption_data.iloc[i]["Sr No."] == "Sr No.":
            a.append(i)

# %%
# dropping unnecessary rows 
redemption_data.drop(axis=0,index = a,inplace = True)

# %%
redemption_data.shape
# Out:
# (20421, 9)

# %%
# redemption_data = pd.DataFrame(redemption_data)

# %%
redemption_data.head()
# Out:
#   Sr No. Date of\rEncashment               Name of the Political Party  \
# 0      1         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1      2         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2      3         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3      4         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4      5         12/Apr/2019  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Account no. of\rPolitical Party Prefix Bond\rNumber Denominations  \
# 0                     *******5199     OC          775   1,00,00,000
# 1                     *******5199     OC         3975   1,00,00,000
# 2                     *******5199     OC         3967   1,00,00,000
# 3                     *******5199     TL        10418     10,00,000
# 4                     *******5199     TL          126     10,00,000
#
#   Pay Branch\rCode Pay Teller
# 0            00800    2770121
# 1            00800    2770121
# 2            00800    2770121
# ...

# %%
type(redemption_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# writing the data to a EB_Redemption_1.csv file

redemption_data.to_csv("G:\\Job Projects\\Project 3 - Electoral Bond Data\\Electroral Bond Data\\ED_Redemption_Details_1.csv",
                     sep = ",",
                     index = False)
